# %% [markdown]
# # Importing the dataset

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn import metrics

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv('energydata_complete.csv')

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4       RH_4         T5   RH_5        T6  \
# 0  19.79  44.730000  19.000000  45.566667  17.166667  55.20  7.026667
# 1  19.79  44.790000  19.000000  45.992500  17.166667  55.20  6.833333
# 2  19.79  44.933333  18.926667  45.890000  17.166667  55.09  6.560000
# 3  19.79  45.000000  18.890000  45.723333  17.166667  55.09  6.433333
# 4  19.79  45.000000  18.890000  45.530000  17.200000  55.09  6.366667
#
#         RH_6         T7       RH_7    T8       RH_8         T9   RH_9  \
# ...

# %%
X = data
y = data.loc[:,'Appliances']

# %%
y = pd.DataFrame(y)

# %%
X
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5       RH_5         T6  \
# ...

# %%
X = X.drop(['date','lights','Appliances'], axis=1)

# %%
M = X.iloc[:]

# rescale X
scaler = MinMaxScaler(feature_range=(0, 1))
X.iloc[:] = scaler.fit_transform(M)

# %%
X.head()
# Out:
#         T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5        T6      RH_6        T7      RH_7  \
# 0  0.764262  0.175506  0.381691  0.381070  0.841827  0.170594  0.653428
# 1  0.782437  0.175506  0.381691  0.375443  0.839872  0.170594  0.651064
# 2  0.778062  0.175506  0.380037  0.367487  0.830704  0.170594  0.646572
# 3  0.770949  0.175506  0.380037  0.363800  0.833401  0.164310  0.641489
# 4  0.762697  0.178691  0.380037  0.361859  0.848264  0.170594  0.639362
#
#          T8      RH_8        T9      RH_9     T_out  Press_mm_hg    RH_out  \
# ...

# %% [markdown]
# ## Question 12

# %%
X_train, X_test, y_train, y_test = train_test_split(X['T2'].values.reshape(-1,1), X['T6'], test_size=0.3, random_state=42)

linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
actual_pred = linear_model.predict(X_test)
R_squared = metrics.r2_score(y_test, actual_pred)
print("The R_squared score: ", R_squared)
# Out:
# The R_squared score:  0.6427789637197383

# %% [markdown]
# ## Question 13

# %%
mean_abs = metrics.mean_absolute_error(y_test, actual_pred)
print('The Mean Absolute Error is: ', mean_abs)
# Out:
# The Mean Absolute Error is:  0.08216970202681717

# %% [markdown]
# ## Question 14

# %%
residual_sum_squares = np.square(y_test - actual_pred)
residual_sum_squares = np.sum(residual_sum_squares)
print("The Residual Sum of Squares: ", residual_sum_squares.round(3))
# Out:
# The Residual Sum of Squares:  284.156

# %% [markdown]
# ## Question 15

# %%
RMSE = metrics.mean_squared_error(y_test, actual_pred)
RMSE = np.sqrt(RMSE)
print('The Root Mean Squared Error: ', RMSE.round(3)) ##########
# Out:
# The Root Mean Squared Error:  0.219

# %% [markdown]
# ## Question 16

# %%
co_eff_det = metrics.r2_score(y_test, actual_pred)
print("The Coefficient of determination: ", co_eff_det.round(3)) ##############
# Out:
# The Coefficient of determination:  -0.535

# %% [markdown]
# ## Question 18

# %%
ridge_1 = Ridge(alpha=0.4, normalize = True)
ridge_1.fit(X_train, y_train) # Fit a ridge regression on the training data
ridge_predict = ridge_1.predict(X_test) # Use this model to predict the test data
print(mean_squared_error(y_test, ridge_predict))
print("The Root Mean Squared Error (Linear): ", mean_abs)
# Out:
# 0.012803469708046335
# The Root Mean Squared Error (Linear):  0.08216970202681717

# %% [markdown]
# ## Question 19

# %%
lass_mod = Lasso(alpha=0.001, normalize = True)
lass_mod.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=True, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
